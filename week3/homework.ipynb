# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv')
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
data = data[['Make',
'Model',
'Year',
'Engine HP',
'Engine Cylinders',
'Transmission Type',
'Vehicle Style',
'highway MPG',
'city mpg',
'MSRP']]

# %%
data.columns = data.columns.str.replace(' ', '_').str.lower()

# %%
data.fillna(0, inplace=True)
data.rename(columns={'msrp': 'price'}, inplace=True)

# %%
data.groupby('transmission_type')['transmission_type'].count()
# Out:
# transmission_type
# AUTOMATED_MANUAL     626
# AUTOMATIC           8266
# DIRECT_DRIVE          68
# MANUAL              2935
# UNKNOWN               19
# Name: transmission_type, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_hp          11914 non-null  float64
#  4   engine_cylinders   11914 non-null  float64
#  5   transmission_type  11914 non-null  object
#  6   vehicle_style      11914 non-null  object
#  7   highway_mpg        11914 non-null  int64
#  8   city_mpg           11914 non-null  int64
#  9   price              11914 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 930.9+ KB

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'price']
categorical = ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
data[numerical].corr()
# Out:
#                       year  engine_hp  engine_cylinders  highway_mpg  \
# year              1.000000   0.338714         -0.040708     0.258240
# engine_hp         0.338714   1.000000          0.774851    -0.415707
# engine_cylinders -0.040708   0.774851          1.000000    -0.614541
# highway_mpg       0.258240  -0.415707         -0.614541     1.000000
# city_mpg          0.198171  -0.424918         -0.587306     0.886829
# price             0.227590   0.650095          0.526274    -0.160043
#
#                   city_mpg     price
# year              0.198171  0.227590
# engine_hp        -0.424918  0.650095
# engine_cylinders -0.587306  0.526274
# highway_mpg       0.886829 -0.160043
# city_mpg          1.000000 -0.157676
# price            -0.157676  1.000000

# %%
data.price = data.price.apply(lambda x: 1 if x > data.price.mean() else 0)

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_full, df_test = train_test_split(data, test_size=0.2, random_state=42)

# %%
df_train, df_val = train_test_split(df_train_full, test_size=0.2, random_state=42)

# %%
y_train = df_train.price.values
y_val = df_val.price.values
y_test = df_test.price.values

del df_train['price']
del df_val['price']
del df_test['price']

# %%
from sklearn.metrics import mutual_info_score

# %%
def calculate_mi(series):
    return mutual_info_score(series, df_train_full.price)

df_mi = df_train_full[categorical].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending=False).to_frame(name='MI')


display(df_mi.head())
display(df_mi.tail())
# Out:
#                          MI
# model              0.460994
# make               0.238724
# vehicle_style      0.083390
# transmission_type  0.020884
#                          MI
# model              0.460994
# make               0.238724
# vehicle_style      0.083390
# transmission_type  0.020884

# %%
numerical.remove('price')

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
results = model.predict(X_val)

# %%
from sklearn.metrics import accuracy_score

round(accuracy_score(y_val, results), 2)
# Out:
# 0.94

# %%
dict(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# Out:
# {'city_mpg': 0.083,
#  'engine_cylinders': -0.054,
#  'engine_hp': 0.036,
#  'highway_mpg': 0.001,
#  'make=Acura': 1.115,
#  'make=Alfa Romeo': 1.244,
#  'make=Aston Martin': 0.434,
#  'make=Audi': 3.177,
#  'make=BMW': 2.455,
#  'make=Bentley': 0.132,
#  'make=Bugatti': 0.0,
#  'make=Buick': -0.432,
#  'make=Cadillac': 2.46,
#  'make=Chevrolet': -1.563,
#  'make=Chrysler': -1.266,
#  'make=Dodge': -2.962,
#  'make=FIAT': -0.395,
#  'make=Ferrari': 0.251,
#  'make=Ford': -2.177,
#  'make=GMC': -0.913,
#  'make=Genesis': 0.353,
#  'make=HUMMER': -0.066,
#  'make=Honda': -1.173,
#  'make=Hyundai': -2.532,
#  'make=Infiniti': 0.353,
#  'make=Kia': -1.521,
#  'make=Lamborghini': 0.007,
#  'make=Land Rover': 1.989,
#  'make=Lexus': 1.275,
#  'make=Lincoln': 1.083,
#  'make=Lotus': 3.517,
#  'make=Maserati': 0.795,
#  'make=Maybach': 0.003,
#  'make=Mazda': -1.529,
#  'make=McLaren': 0.0,
#  'make=Mercedes-Benz': 0.899,
#  'make=Mitsubishi': -1.516,
#  'make=Nissan': -1.192,
#  'make=Oldsmobile': -0.991,
#  'make=Plymouth': -0.144,
#  'make=Pontiac': -2.462,
#  'make=Porsche': 1.8,
#  'make=Rolls-Royce': 0.643,
#  'make=Saab': 0.754,
#  'make=Scion': -0.174,
#  'make=Spyker': 0.2,
#  'make=Subaru': -2.25,
#  'make=Suzuki': -1.501,
#  'make=Tesla': 2.511,
#  'make=Toyota': -1.071,
#  'make=Volkswagen': -0.875,
#  'make=Volvo': 1.059,
#  'model=1 Series': -0.751,
#  'model=100': -0.169,
#  'model=124 Spider': -0.029,
#  'model=190-Class': -0.005,
#  'model=2': -0.002,
#  'model=2 Series': -0.836,
#  'model=200': -0.679,
#  'model=200SX': -0.002,
#  'model=240': -0.002,
#  'model=240SX': -0.002,
#  'model=3': -0.161,
#  'model=3 Series': -0.172,
#  'model=3 Series Gran Turismo': 1.182,
#  'model=300': -0.079,
#  'model=300-Class': -0.328,
#  'model=3000GT': -0.054,
#  'model=300M': -0.13,
#  'model=300ZX': -0.085,
#  'model=323': -0.0,
#  'model=350-Class': -0.008,
#  'model=350Z': -0.738,
#  'model=360': 0.114,
#  'model=370Z': 0.139,
#  'model=4 Series': 1.068,
#  'model=4 Series Gran Coupe': 0.644,
#  'model=400-Class': -0.323,
#  'model=420-Class': -0.034,
#  'model=456M': 0.062,
#  'model=458 Italia': 0.0,
#  'model=4C': 1.244,
#  'model=4Runner': 0.426,
#  'model=5': -0.018,
#  'model=5 Series': 0.852,
#  'model=5 Series Gran Turismo': 0.538,
#  'model=500': -0.035,
#  'model=500-Class': -1.423,
#  'model=500L': -0.033,
#  'model=500X': -0.198,
#  'model=500e': -0.1,
#  'model=550': 0.017,
#  'model=560-Class': -0.124,
#  'model=57': 0.001,
#  'model=570S': 0.0,
#  'model=575M': 0.016,
#  'model=599': 0.0,
#  'model=6': -0.085,
#  'model=6 Series': 0.284,
#  'model=6 Series Gran Coupe': 0.14,
#  'model=600-Class': -1.25,
#  'model=6000': -0.003,
#  'model=612 Scaglietti': 0.001,
#  'model=62': 0.002,
#  'model=626': -0.006,
#  'model=7 Series': 0.149,
#  'model=740': -0.023,
#  'model=760': -0.003,
#  'model=780': -0.01,
#  'model=8 Series': -0.765,
#  'model=80': -0.021,
#  'model=850': -0.636,
#  'model=86': -0.004,
#  'model=9-2X': -0.075,
#  'model=9-3': 0.842,
#  'model=9-3 Griffin': 0.403,
#  'model=9-4X': -0.526,
#  'model=9-5': 0.323,
#  'model=9-7X': 0.023,
#  'model=90': -0.107,
#  'model=900': -0.169,
#  'model=9000': -0.066,
#  'model=911': 0.653,
#  'model=928': -0.378,
#  'model=929': -0.007,
#  'model=940': -0.054,
#  'model=944': -0.174,
#  'model=960': -0.039,
#  'model=968': -0.343,
#  'model=A3': -0.659,
#  'model=A4': -0.631,
#  'model=A5': 1.075,
#  'model=A6': 0.916,
#  'model=A7': 0.399,
#  'model=A8': 0.154,
#  'model=ALPINA B6 Gran Coupe': 0.0,
#  'model=ALPINA B7': 0.0,
#  'model=AMG GT': 0.001,
#  'model=ATS': -1.257,
#  'model=ATS Coupe': -0.066,
#  'model=Acadia': 1.316,
#  'model=Acadia Limited': 0.598,
#  'model=Accent': -0.007,
#  'model=Acclaim': -0.002,
#  'model=Accord': -0.805,
#  'model=Accord Crosstour': -0.106,
#  'model=Accord Hybrid': -0.128,
#  'model=Accord Plug-In Hybrid': -0.037,
#  'model=Achieva': -0.006,
#  'model=ActiveHybrid 5': 0.055,
#  'model=ActiveHybrid 7': 0.03,
#  'model=ActiveHybrid X6': 0.001,
#  'model=Aerio': -0.047,
#  'model=Aerostar': -0.005,
#  'model=Alero': -0.045,
#  'model=Allante': -0.152,
#  'model=Altima': -0.464,
#  'model=Altima Hybrid': -0.017,
#  'model=Amanti': -0.062,
#  'model=Armada': 1.644,
#  'model=Arnage': 0.034,
#  'model=Aspen': -0.316,
#  'model=Aspire': -0.0,
#  'model=Astro': -0.009,
#  'model=Astro Cargo': -0.006,
#  'model=Aurora': -0.06,
#  'model=Avalanche': 1.058,
#  'model=Avalon': -0.593,
#  'model=Avalon Hybrid': 0.686,
#  'model=Avenger': -0.075,
#  'model=Aventador': 0.0,
#  'model=Aveo': -0.002,
#  'model=Aviator': -0.032,
#  'model=Axxess': -0.001,
#  'model=Azera': -0.195,
#  'model=Aztek': -0.017,
#  'model=Azure': 0.008,
#  'model=Azure T': 0.001,
#  'model=B-Class Electric Drive': -0.252,
#  'model=B-Series': -0.002,
#  'model=B-Series Pickup': -0.003,
#  'model=B-Series Truck': -0.004,
#  'model=B9 Tribeca': -0.53,
#  'model=BRZ': -0.03,
#  'model=Baja': -0.028,
#  'model=Beetle': -0.175,
#  'model=Beetle Convertible': -1.165,
#  'model=Beretta': -0.003,
#  'model=Black Diamond Avalanche': 0.403,
#  'model=Blackwood': 0.205,
#  'model=Blazer': -0.018,
#  'model=Bonneville': -0.11,
#  'model=Borrego': -0.969,
#  'model=Boxster': 0.472,
#  'model=Bravada': -0.471,
#  'model=Breeze': -0.001,
#  'model=Bronco': -0.005,
#  'model=Bronco II': -0.001,
#  'model=Brooklands': 0.002,
#  'model=Brougham': -0.059,
#  'model=C-Class': 1.026,
#  'model=C-Max Hybrid': -0.055,
#  'model=C/K 1500 Series': -0.018,
#  'model=C/K 2500 Series': -0.006,
#  'model=C30': -0.068,
#  'model=C43 AMG': -0.27,
#  'model=C70': 0.022,
#  'model=C8': 0.2,
#  'model=CC': 0.533,
#  'model=CL': -0.271,
#  'model=CL-Class': 0.01,
#  'model=CLA-Class': -0.346,
#  'model=CLK-Class': 0.784,
#  'model=CLS-Class': 0.132,
#  'model=CR-V': -0.326,
#  'model=CR-Z': -0.014,
#  'model=CT 200h': -0.008,
#  'model=CT6': 0.328,
#  'model=CTS': 0.961,
#  'model=CTS Coupe': 0.078,
#  'model=CTS Wagon': 0.117,
#  'model=CTS-V': 0.0,
#  'model=CTS-V Coupe': 0.0,
#  'model=CTS-V Wagon': 0.0,
#  'model=CX-3': -0.048,
#  'model=CX-5': -0.231,
#  'model=CX-7': -0.318,
#  'model=CX-9': 0.098,
#  'model=Cabrio': -0.017,
#  'model=Cabriolet': -0.127,
#  'model=Cadenza': 0.412,
#  'model=Caliber': -0.007,
#  'model=California T': 0.0,
#  'model=Camaro': -1.743,
#  'model=Camry': -0.51,
#  'model=Camry Hybrid': -0.172,
#  'model=Camry Solara': -0.286,
#  'model=Canyon': -1.452,
#  'model=Caprice': -0.056,
#  'model=Captiva Sport': -0.035,
#  'model=Caravan': -0.005,
#  'model=Carrera GT': 0.0,
#  'model=Cascada': -0.09,
#  'model=Catera': -0.116,
#  'model=Cavalier': -0.007,
#  'model=Cayenne': 0.082,
#  'model=Cayman': 0.519,
#  'model=Cayman S': 0.25,
#  'model=Celebrity': -0.001,
#  'model=Celica': -0.022,
#  'model=Century': -0.009,
#  'model=Challenger': -1.196,
#  'model=Charger': -1.458,
#  'model=Chevy Van': -0.011,
#  'model=Ciera': -0.003,
#  'model=Cirrus': -0.002,
#  'model=City Express': -0.001,
#  'model=Civic': -0.233,
#  'model=Civic CRX': -0.001,
#  'model=Civic del Sol': -0.002,
#  'model=Classic': -0.001,
#  'model=Cobalt': -0.068,
#  'model=Colorado': -1.056,
#  'model=Colt': -0.008,
#  'model=Concorde': -0.094,
#  'model=Continental': 1.367,
#  'model=Continental Flying Spur': 0.0,
#  'model=Continental Flying Spur Speed': 0.0,
#  'model=Continental GT': 0.004,
#  'model=Continental GT Speed': 0.0,
#  'model=Continental GT Speed Convertible': 0.0,
#  'model=Continental GTC': 0.0,
#  'model=Continental GTC Speed': 0.0,
#  'model=Continental Supersports': 0.0,
#  'model=Continental Supersports Convertible': 0.0,
#  'model=Contour': -0.001,
#  'model=Corniche': 0.094,
#  'model=Corolla': -0.068,
#  'model=Corolla iM': -0.002,
#  'model=Corrado': -0.002,
#  'model=Corvette': 0.4,
#  'model=Corvette Stingray': 0.028,
#  'model=Coupe': 0.269,
#  'model=Cressida': -0.004,
#  'model=Crossfire': -0.05,
#  'model=Crosstour': -0.377,
#  'model=Crosstrek': -0.015,
#  'model=Crown Victoria': -0.016,
#  'model=Cruze': -0.055,
#  'model=Cruze Limited': -0.012,
#  'model=Cube': -0.005,
#  'model=Custom Cruiser': -0.003,
#  'model=Cutlass': -0.009,
#  'model=Cutlass Calais': -0.018,
#  'model=Cutlass Ciera': -0.015,
#  'model=Cutlass Supreme': -0.023,
#  'model=DB7': 0.014,
#  'model=DB9': 0.005,
#  'model=DB9 GT': 0.001,
#  'model=DBS': 0.019,
#  'model=DTS': 0.897,
#  'model=Dakota': -0.091,
#  'model=Dart': -0.026,
#  'model=Dawn': 0.0,
#  'model=Daytona': -0.003,
#  'model=DeVille': 0.996,
#  'model=Defender': -0.039,
#  'model=Diablo': 0.002,
#  'model=Diamante': -0.034,
#  'model=Discovery': 0.193,
#  'model=Discovery Series II': -0.112,
#  'model=Discovery Sport': -0.241,
#  'model=Durango': 2.46,
#  'model=Dynasty': -0.001,
#  'model=E-150': -0.006,
#  'model=E-250': -0.007,
#  'model=E-Class': 2.641,
#  'model=E-Series Van': -0.037,
#  'model=E-Series Wagon': -0.082,
#  'model=E55 AMG': -0.765,
#  'model=ECHO': -0.006,
#  'model=ES 250': -0.002,
#  'model=ES 300': -0.097,
#  'model=ES 300h': 0.439,
#  'model=EX': -1.459,
#  'model=EX35': -1.861,
#  'model=Eclipse': -0.032,
#  'model=Eclipse Spyder': -0.293,
#  'model=Edge': -0.92,
#  'model=Eighty-Eight': -0.083,
#  'model=Eighty-Eight Royale': -0.041,
#  'model=Elantra': -0.046,
#  'model=Elantra Coupe': -0.008,
#  'model=Elantra GT': -0.006,
#  'model=Elantra Touring': -0.003,
#  'model=Eldorado': -0.131,
#  'model=Electra': -0.006,
#  'model=Element': -0.037,
#  'model=Elise': 1.119,
#  'model=Enclave': 1.325,
#  'model=Encore': -0.095,
#  'model=Endeavor': -0.128,
#  'model=Entourage': -0.054,
#  'model=Envision': 0.77,
#  'model=Envoy': -1.117,
#  'model=Envoy XL': -0.949,
#  'model=Envoy XUV': -0.16,
#  'model=Eos': 0.283,
#  'model=Equator': -0.185,
#  'model=Equinox': -0.182,
#  'model=Equus': 0.157,
#  'model=Escalade': 0.033,
#  'model=Escalade ESV': 0.02,
#  'model=Escalade EXT': 0.04,
#  'model=Escalade Hybrid': 0.149,
#  'model=Escape': -0.054,
#  'model=Escape Hybrid': -0.069,
#  'model=Escort': -0.002,
#  'model=Esprit': 0.167,
#  'model=Esteem': -0.015,
#  'model=EuroVan': -0.022,
#  'model=Evora': 1.106,
#  'model=Excel': -0.0,
#  'model=Exige': 1.124,
#  'model=Expedition': 1.546,
#  'model=Explorer': 0.077,
#  'model=Explorer Sport': -0.03,
#  'model=Explorer Sport Trac': -0.413,
#  'model=Expo': -0.002,
#  'model=Express': -0.293,
#  'model=Express Cargo': -0.042,
#  'model=F-150': 0.861,
#  'model=F-150 Heritage': -0.01,
#  'model=F-150 SVT Lightning': -0.066,
#  'model=F-250': -0.017,
#  'model=F12 Berlinetta': 0.0,
#  'model=F430': 0.041,
#  'model=FF': 0.0,
#  'model=FJ Cruiser': -0.292,
#  'model=FR-S': -0.091,
#  'model=FX': 0.675,
#  'model=FX35': 0.19,
#  'model=FX45': 0.147,
#  'model=FX50': 0.017,
#  'model=Festiva': -0.0,
#  'model=Fiesta': -0.006,
#  'model=Firebird': -0.462,
#  'model=Fit': -0.008,
#  'model=Five Hundred': -0.043,
#  'model=Fleetwood': -0.431,
#  'model=Flex': -0.084,
#  'model=Flying Spur': 0.001,
#  'model=Focus': -0.037,
#  'model=Focus ST': -0.028,
#  'model=Forenza': -0.014,
#  'model=Forester': -0.271,
#  'model=Forte': -0.048,
#  'model=Fox': -0.0,
#  'model=Freelander': -0.192,
#  'model=Freestar': -0.014,
#  'model=Freestyle': -0.051,
#  'model=Frontier': -0.702,
#  'model=Fusion': -0.155,
#  'model=Fusion Hybrid': -0.085,
#  'model=G Convertible': 0.369,
#  'model=G Coupe': 0.279,
#  'model=G Sedan': -0.926,
#  'model=G-Class': 0.017,
#  'model=G20': -0.012,
#  'model=G3': -0.0,
#  'model=G35': -1.215,
#  'model=G37': -1.168,
#  'model=G37 Convertible': 0.177,
#  'model=G37 Coupe': -0.417,
#  'model=G37 Sedan': -0.381,
#  'model=G5': -0.004,
#  'model=G6': -0.173,
#  'model=G8': -0.595,
#  'model=G80': 0.353,
#  'model=GL-Class': 0.466,
#  'model=GLA-Class': -0.43,
#  'model=GLC-Class': -0.236,
#  'model=GLE-Class': 0.539,
#  'model=GLE-Class Coupe': 0.013,
#  'model=GLI': -0.12,
#  'model=GLK-Class': -1.491,
#  'model=GLS-Class': 0.001,
#  'model=GS 200t': 0.936,
#  'model=GS 300': 0.462,
#  'model=GS 350': 0.554,
#  'model=GS 400': -0.514,
#  'model=GS 430': 0.156,
#  'model=GS 450h': 0.042,
#  'model=GS 460': 0.15,
#  'model=GT': 0.006,
#  'model=GT-R': 0.004,
#  'model=GTI': -0.183,
#  'model=GTO': -0.442,
#  'model=GX 460': 0.203,
#  'model=GX 470': 0.648,
#  'model=Galant': -0.01,
#  'model=Gallardo': 0.005,
#  'model=Genesis': 0.2,
#  'model=Genesis Coupe': -0.948,
#  'model=Ghibli': 0.207,
#  'model=Ghost': 0.0,
#  'model=Ghost Series II': 0.0,
#  'model=Golf': -0.06,
#  'model=Golf Alltrack': -0.006,
#  'model=Golf GTI': -0.236,
#  'model=Golf R': -0.241,
#  'model=Golf SportWagen': -0.102,
#  'model=GranSport': 0.079,
#  'model=GranTurismo': 0.032,
#  'model=GranTurismo Convertible': 0.011,
#  'model=Grand Am': -0.015,
#  'model=Grand Caravan': -0.202,
#  'model=Grand Prix': -0.287,
#  'model=Grand Vitara': -0.039,
#  'model=Grand Voyager': -0.014,
#  'model=H3': 0.313,
#  'model=H3T': -0.379,
#  'model=HHR': -0.073,
#  'model=HR-V': -0.031,
#  'model=HS 250h': -0.3,
#  'model=Highlander': 0.403,
#  'model=Highlander Hybrid': 0.45,
#  'model=Horizon': -0.0,
#  'model=Huracan': 0.0,
#  'model=I30': -0.139,
#  'model=I35': -0.137,
#  'model=ILX': -0.452,
#  'model=ILX Hybrid': -0.007,
#  'model=IS 200t': -0.343,
#  'model=IS 250': -0.242,
#  'model=IS 250 C': 0.256,
#  'model=IS 300': -0.111,
#  'model=IS 350': -0.34,
#  'model=IS 350 C': 0.032,
#  'model=IS F': 0.006,
#  'model=Impala': 0.076,
#  'model=Impala Limited': -0.406,
#  'model=Imperial': -0.001,
#  'model=Impreza': -0.044,
#  'model=Impreza WRX': -0.198,
#  'model=Insight': -0.006,
#  'model=Integra': -0.059,
#  'model=Intrepid': -0.03,
#  'model=Intrigue': -0.077,
#  'model=J30': -0.062,
#  'model=JX': 0.261,
#  'model=Jetta': -0.329,
#  'model=Jetta GLI': -0.343,
#  'model=Jetta Hybrid': -0.106,
#  'model=Jetta SportWagen': -0.1,
#  'model=Jimmy': -0.123,
#  'model=Journey': -0.442,
#  'model=Juke': -0.074,
#  'model=Justy': -0.0,
#  'model=K900': 0.387,
#  'model=Kizashi': -0.111,
#  'model=LFA': 0.0,
#  'model=LHS': -0.053,
#  'model=LR2': 0.136,
#  'model=LR3': 0.197,
#  'model=LR4': 0.139,
#  'model=LS': -0.289,
#  'model=LS 400': -0.475,
#  'model=LS 430': 0.362,
#  'model=LS 460': 0.211,
#  'model=LS 600h L': 0.003,
#  'model=LSS': -0.02,
#  'model=LTD Crown Victoria': -0.003,
#  'model=LX 450': -0.048,
#  'model=LX 470': 0.341,
#  'model=LX 570': 0.038,
#  'model=LaCrosse': -1.147,
#  'model=Lancer': -0.022,
#  'model=Lancer Evolution': -0.304,
#  'model=Lancer Sportback': -0.008,
#  'model=Land Cruiser': 0.053,
#  'model=Laser': -0.011,
#  'model=Le Baron': -0.008,
#  'model=Le Mans': -0.001,
#  'model=LeSabre': -0.05,
#  'model=Leaf': -0.037,
#  'model=Legacy': -0.124,
#  'model=Legend': -0.216,
#  'model=Levante': 0.005,
#  'model=Loyale': -0.0,
#  'model=Lucerne': 0.386,
#  'model=Lumina': -0.012,
#  'model=Lumina Minivan': -0.002,
#  'model=M': 0.713,
#  'model=M-Class': 0.895,
#  'model=M2': 0.061,
#  'model=M3': 0.007,
#  'model=M30': -0.036,
#  'model=M35': 1.086,
#  'model=M37': 0.132,
#  'model=M4': 0.015,
#  'model=M4 GTS': 0.0,
#  'model=M45': 0.686,
#  'model=M5': 0.0,
#  'model=M56': 0.021,
#  'model=M6': 0.0,
#  'model=M6 Gran Coupe': 0.0,
#  'model=MDX': 1.351,
#  'model=MKC': -0.102,
#  'model=MKS': -0.436,
#  'model=MKT': 0.258,
#  'model=MKX': -0.593,
#  'model=MKZ': 0.651,
#  'model=MKZ Hybrid': -0.088,
#  'model=MP4-12C': 0.0,
#  'model=MPV': -0.048,
#  'model=MR2': -0.003,
#  'model=MR2 Spyder': -0.02,
#  'model=MX-3': -0.001,
#  'model=MX-5 Miata': -0.14,
#  'model=MX-6': -0.002,
#  'model=Macan': 0.309,
#  'model=Magnum': -0.901,
#  'model=Malibu': -0.181,
#  'model=Malibu Classic': -0.021,
#  'model=Malibu Hybrid': -0.006,
#  'model=Malibu Limited': -0.038,
#  'model=Malibu Maxx': -0.027,
#  'model=Mark LT': -0.493,
#  'model=Mark VII': -0.236,
#  'model=Mark VIII': -0.698,
#  'model=Matrix': -0.005,
#  'model=Maxima': -0.81,
#  'model=Maybach': 0.0,
#  'model=Mazdaspeed 3': -0.01,
#  'model=Mazdaspeed 6': -0.047,
#  'model=Mazdaspeed MX-5 Miata': -0.015,
#  'model=Mazdaspeed Protege': -0.003,
#  'model=Metris': -0.096,
#  'model=Metro': -0.0,
#  'model=Mighty Max Pickup': -0.0,
#  'model=Millenia': -0.048,
#  'model=Mirage': -0.005,
#  'model=Mirage G4': -0.001,
#  'model=Model S': 2.511,
#  'model=Monaco': -0.001,
#  'model=Montana': -0.033,
#  'model=Montana SV6': -0.008,
#  'model=Monte Carlo': -0.168,
#  'model=Montero': -0.025,
#  'model=Montero Sport': -0.107,
#  'model=Mulsanne': 0.002,
#  'model=Murano': 0.68,
#  'model=Murano CrossCabriolet': 0.79,
#  'model=Murcielago': 0.0,
#  'model=Mustang': -1.511,
#  'model=Mustang SVT Cobra': -0.448,
#  'model=NSX': 1.23,
#  'model=NV200': -0.003,
#  'model=NX': -0.001,
#  'model=NX 200t': -1.456,
#  'model=NX 300h': 0.179,
#  'model=Navajo': -0.004,
#  'model=Navigator': 0.111,
#  'model=Neon': -0.018,
#  'model=New Beetle': -0.079,
#  'model=New Yorker': -0.016,
#  'model=Ninety-Eight': -0.033,
#  'model=Nitro': -0.127,
#  'model=Odyssey': 1.203,
#  'model=Omni': -0.0,
#  'model=Optima': -0.377,
#  'model=Optima Hybrid': -0.071,
#  'model=Outback': -0.259,
#  'model=Outlander': -0.127,
#  'model=Outlander Sport': -0.127,
#  'model=PT Cruiser': -0.01,
#  'model=Pacifica': -0.23,
#  'model=Panamera': 0.412,
#  'model=Park Avenue': 0.356,
#  'model=Paseo': -0.001,
#  'model=Passat': -0.33,
#  'model=Passport': -0.077,
#  'model=Pathfinder': -0.019,
#  'model=Phaeton': 0.963,
#  'model=Phantom': 0.033,
#  'model=Phantom Coupe': 0.018,
#  'model=Phantom Drophead Coupe': 0.004,
#  'model=Pickup': -0.001,
#  'model=Pilot': -0.108,
#  'model=Precis': -0.0,
#  'model=Prelude': -0.009,
#  'model=Previa': -0.015,
#  'model=Prius': -0.043,
#  'model=Prius Prime': -0.004,
#  'model=Prius c': -0.011,
#  'model=Prius v': -0.044,
#  'model=Prizm': -0.002,
#  'model=Probe': -0.001,
#  'model=Protege': -0.001,
#  'model=Protege5': -0.0,
#  'model=Prowler': 0.624,
#  'model=Q3': -1.021,
#  'model=Q40': -0.318,
#  'model=Q45': 0.239,
#  'model=Q5': 0.609,
#  'model=Q50': 0.613,
#  'model=Q60 Convertible': 0.282,
#  'model=Q60 Coupe': 1.634,
#  'model=Q7': 0.527,
#  'model=Q70': 0.876,
#  'model=QX': 0.037,
#  'model=QX4': -0.173,
#  'model=QX50': -1.61,
#  'model=QX56': 0.291,
#  'model=QX60': 1.413,
#  'model=QX70': 0.31,
#  'model=QX80': 0.063,
#  'model=Quattroporte': 0.117,
#  'model=Quest': 0.267,
#  'model=R-Class': 1.233,
#  'model=R32': -0.011,
#  'model=R8': 0.015,
#  'model=RAM 150': -0.004,
#  'model=RAM 250': -0.003,
#  'model=RAV4': -0.241,
#  'model=RAV4 EV': 0.572,
#  'model=RAV4 Hybrid': -0.112,
#  'model=RC 200t': -0.279,
#  'model=RC 300': 0.587,
#  'model=RC 350': 0.357,
#  'model=RC F': 0.001,
#  'model=RDX': -1.996,
#  'model=RL': 0.93,
#  'model=RLX': 0.508,
#  'model=RS 4': 0.015,
#  'model=RS 5': 0.003,
#  'model=RS 7': 0.0,
#  'model=RSX': -0.03,
#  'model=RX 300': -0.459,
#  'model=RX 330': -0.493,
#  'model=RX 350': 0.485,
#  'model=RX 400h': 0.26,
#  'model=RX 450h': 0.13,
#  'model=RX-7': -0.03,
#  'model=RX-8': -0.045,
#  'model=Rabbit': -0.012,
#  'model=Raider': -0.06,
#  'model=Rainier': -0.656,
#  'model=Rally Wagon': -0.006,
#  'model=Ram 50 Pickup': -0.0,
#  'model=Ram Cargo': -0.004,
#  'model=Ram Pickup 1500': -0.761,
#  'model=Ram Van': -0.006,
#  'model=Ram Wagon': -0.001,
#  'model=Ramcharger': -0.014,
#  'model=Range Rover': 0.159,
#  'model=Range Rover Evoque': 1.506,
#  'model=Range Rover Sport': 0.244,
#  'model=Ranger': -0.011,
#  'model=Rapide': 0.012,
#  'model=Rapide S': 0.0,
#  'model=Reatta': -0.018,
#  'model=Regal': -0.492,
#  'model=Regency': -0.011,
#  'model=Rendezvous': -0.038,
#  'model=Reno': -0.004,
#  'model=Reventon': 0.0,
#  'model=Ridgeline': 0.067,
#  'model=Rio': -0.023,
#  'model=Riviera': -0.035,
#  'model=Roadmaster': -0.264,
#  'model=Rogue': -0.141,
#  'model=Rogue Select': -0.022,
#  'model=Rondo': -0.019,
#  'model=Routan': -0.262,
#  'model=S-10': -0.007,
#  'model=S-10 Blazer': -0.011,
#  'model=S-15': -0.001,
#  'model=S-15 Jimmy': -0.007,
#  'model=S-Class': 0.007,
#  'model=S2000': -0.139,
#  'model=S3': 0.157,
#  'model=S4': 0.191,
#  'model=S40': -0.273,
#  'model=S5': 0.176,
#  'model=S6': 0.004,
#  'model=S60': -0.479,
#  'model=S60 Cross Country': 0.309,
#  'model=S7': 0.003,
#  'model=S70': -0.148,
#  'model=S8': 0.0,
#  'model=S80': 0.399,
#  'model=S90': 0.068,
#  'model=SC 300': -0.136,
#  'model=SC 400': -0.412,
#  'model=SC 430': 0.152,
#  'model=SL-Class': 0.023,
#  'model=SLC-Class': 0.005,
#  'model=SLK-Class': 0.487,
#  'model=SLR McLaren': 0.0,
#  'model=SLS AMG': 0.0,
#  'model=SLS AMG GT': 0.0,
#  'model=SLS AMG GT Final Edition': 0.0,
#  'model=SLX': -0.084,
#  'model=SQ5': 0.033,
#  'model=SRT Viper': 0.001,
#  'model=SRX': -0.552,
#  'model=STS': 0.373,
#  'model=STS-V': 0.002,
#  'model=SVX': -0.022,
#  'model=SX4': -0.024,
#  'model=Safari': -0.01,
#  'model=Safari Cargo': -0.01,
#  'model=Samurai': -0.0,
#  'model=Santa Fe': -0.646,
#  'model=Santa Fe Sport': -0.279,
#  'model=Savana': -0.449,
#  'model=Savana Cargo': -0.239,
#  'model=Scoupe': -0.001,
#  'model=Sebring': -0.24,
#  'model=Sedona': -0.073,
#  'model=Sentra': -0.038,
#  'model=Sephia': -0.003,
#  'model=Sequoia': 0.752,
#  'model=Seville': 0.409,
#  'model=Shadow': -0.002,
#  'model=Shelby GT350': 0.022,
#  'model=Shelby GT500': 0.0,
#  'model=Sidekick': -0.005,
#  'model=Sienna': 0.376,
#  'model=Sierra 1500': 1.157,
#  'model=Sierra 1500 Classic': -0.687,
#  'model=Sierra 1500 Hybrid': 0.591,
#  'model=Sierra 1500HD': -0.384,
#  'model=Sierra C3': -0.042,
#  'model=Sierra Classic 1500': -0.004,
#  'model=Sigma': -0.001,
#  'model=Silhouette': -0.065,
#  'model=Silver Seraph': 0.494,
#  'model=Silverado 1500': 1.427,
#  'model=Silverado 1500 Classic': -0.43,
#  'model=Silverado 1500 Hybrid': 1.109,
#  'model=Sixty Special': -0.056,
#  'model=Skylark': -0.012,
#  'model=Solstice': -0.142,
#  'model=Sonata': -0.248,
#  'model=Sonata Hybrid': -0.065,
#  'model=Sonic': -0.025,
#  'model=Sonoma': -0.003,
#  'model=Sorento': -0.402,
#  'model=Soul': -0.017,
#  'model=Soul EV': -0.025,
#  'model=Spark': -0.003,
#  'model=Spark EV': -1.197,
#  'model=Spectra': -0.014,
#  'model=Spirit': -0.0,
#  'model=Sportage': -0.217,
#  'model=Sportvan': -0.005,
#  'model=Spyder': 0.053,
#  'model=Stanza': -0.003,
#  'model=Stealth': -0.046,
#  'model=Stratus': -0.013,
#  'model=Suburban': 0.886,
#  'model=Sunbird': -0.003,
#  'model=Sundance': -0.002,
#  'model=Sunfire': -0.001,
#  'model=Supra': -0.003,
#  'model=Swift': -0.001,
#  'model=Syclone': -0.015,
#  'model=T100': -0.004,
#  'model=TL': 0.098,
#  'model=TLX': -0.283,
#  'model=TSX': -0.557,
#  'model=TSX Sport Wagon': -0.249,
#  'model=TT': 0.428,
#  'model=TT RS': 0.027,
#  'model=TTS': 0.114,
#  'model=Tacoma': -0.685,
#  'model=Tahoe': 1.284,
#  'model=Tahoe Hybrid': 0.685,
#  'model=Tahoe Limited/Z71': -0.04,
#  'model=Taurus': -0.732,
#  'model=Taurus X': -0.233,
#  'model=Tempo': -0.001,
#  'model=Tercel': -0.001,
#  'model=Terrain': -0.288,
#  'model=Terraza': -0.144,
#  'model=Thunderbird': -0.652,
#  'model=Tiburon': -0.006,
#  'model=Tiguan': -0.29,
#  'model=Titan': -1.124,
#  'model=Toronado': -0.007,
#  'model=Torrent': -0.149,
#  'model=Touareg': 2.318,
#  'model=Touareg 2': 0.03,
#  'model=Town Car': 1.539,
#  'model=Town and Country': -0.189,
#  'model=Tracker': -0.01,
#  'model=TrailBlazer': -2.298,
#  'model=TrailBlazer EXT': -0.501,
#  'model=Trans Sport': -0.013,
#  'model=Transit Connect': -0.067,
#  'model=Transit Wagon': 1.325,
#  'model=Traverse': 0.245,
#  'model=Trax': -0.039,
#  'model=Tribeca': -0.178,
#  'model=Tribute': -0.301,
#  'model=Tribute Hybrid': -0.042,
#  'model=Truck': -0.005,
#  'model=Tucson': -0.069,
#  'model=Tundra': -0.996,
#  'model=Typhoon': -0.115,
#  'model=Uplander': -0.166,
#  'model=V12 Vanquish': 0.021,
#  'model=V12 Vantage': 0.008,
#  'model=V12 Vantage S': 0.001,
#  'model=V40': -0.052,
#  'model=V50': -0.302,
#  'model=V60': -0.33,
#  'model=V60 Cross Country': 1.048,
#  'model=V70': -0.088,
#  'model=V8 Vantage': 0.352,
#  'model=V90': -0.013,
#  'model=Van': -0.0,
#  'model=Vanagon': -0.001,
#  'model=Vandura': -0.004,
#  'model=Vanquish': 0.001,
#  'model=Vanwagon': -0.0,
#  'model=Veloster': -0.036,
#  'model=Venture': -0.032,
#  'model=Venza': -0.632,
#  'model=Veracruz': -0.259,
#  'model=Verano': -0.213,
#  'model=Verona': -0.007,
#  'model=Versa': -0.01,
#  'model=Versa Note': -0.005,
#  'model=Veyron 16.4': 0.0,
#  'model=Vibe': -0.003,
#  'model=Vigor': -0.02,
#  'model=Viper': 0.005,
#  'model=Virage': 0.001,
#  'model=Vitara': -0.01,
#  'model=Voyager': -0.024,
#  'model=WRX': -0.518,
#  'model=Windstar': -0.044,
#  'model=Windstar Cargo': -0.008,
#  'model=Wraith': 0.0,
#  'model=X-90': -0.001,
#  'model=X1': -1.179,
#  'model=X3': 0.028,
#  'model=X4': 0.397,
#  'model=X5': 0.308,
#  'model=X5 M': 0.0,
#  'model=X6': 0.152,
#  'model=X6 M': 0.0,
#  'model=XC': -0.023,
#  'model=XC60': 0.063,
#  'model=XC70': 0.727,
#  'model=XC90': 0.977,
#  'model=XG300': -0.003,
#  'model=XG350': -0.01,
#  'model=XL-7': -0.098,
#  'model=XL7': -0.938,
#  'model=XLR': 0.103,
#  'model=XLR-V': 0.002,
#  'model=XT': -0.001,
#  'model=XT5': 0.074,
#  'model=XTS': 0.696,
#  'model=XV Crosstrek': -0.033,
#  'model=Xterra': -0.415,
#  'model=Yaris': -0.006,
#  'model=Yaris iA': -0.001,
#  'model=Yukon': 0.444,
#  'model=Yukon Denali': -0.034,
#  'model=Yukon Hybrid': 0.654,
#  'model=Yukon XL': 0.585,
#  'model=Z3': -0.475,
#  'model=Z4': 0.209,
#  'model=Z4 M': 0.249,
#  'model=Z8': 0.014,
#  'model=ZDX': 1.221,
#  'model=allroad': 1.135,
#  'model=allroad quattro': 0.079,
#  'model=e-Golf': -0.807,
#  'model=i-MiEV': -0.177,
#  'model=i3': 0.006,
#  'model=iA': -0.004,
#  'model=iQ': -0.002,
#  'model=tC': -0.047,
#  'model=xA': -0.003,
#  'model=xB': -0.021,
#  'model=xD': -0.005,
#  'transmission_type=AUTOMATED_MANUAL': 0.403,
#  'transmission_type=AUTOMATIC': 0.046,
#  'transmission_type=DIRECT_DRIVE': 0.451,
#  'transmission_type=MANUAL': -1.016,
#  'transmission_type=UNKNOWN': -0.079,
#  'vehicle_style=2dr Hatchback': -1.483,
#  'vehicle_style=2dr SUV': 0.313,
#  'vehicle_style=4dr Hatchback': -1.1,
#  'vehicle_style=4dr SUV': 1.06,
#  'vehicle_style=Cargo Minivan': -0.112,
#  'vehicle_style=Cargo Van': -0.352,
#  'vehicle_style=Convertible': 2.311,
#  'vehicle_style=Convertible SUV': 0.772,
#  'vehicle_style=Coupe': 0.137,
#  'vehicle_style=Crew Cab Pickup': 0.556,
#  'vehicle_style=Extended Cab Pickup': -1.381,
#  'vehicle_style=Passenger Minivan': 0.188,
#  'vehicle_style=Passenger Van': 0.485,
#  'vehicle_style=Regular Cab Pickup': -2.411,
#  'vehicle_style=Sedan': 0.174,
#  'vehicle_style=Wagon': 0.649,
#  'year': -0.006}

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=False)
lst = categorical+numerical[::-1]
for i in categorical+numerical:
    lst.remove(i)
    print(i)
    train_dict = df_train[lst].to_dict(orient='records')
    X_train = dv.fit_transform(train_dict)

    val_dict = df_val[lst].to_dict(orient='records')
    X_val = dv.transform(val_dict)



    model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)

    results = model.predict(X_val)
    print(round(accuracy_score(y_val, results), 3) - 0.94)
# Out:
# make
# 0.0050000000000000044
# model
# -0.05899999999999994
# transmission_type
# -0.06099999999999994
# vehicle_style
# -0.06299999999999994
# year
# -0.061999999999999944
# engine_hp
# -0.1449999999999999
# engine_cylinders
# -0.21399999999999997
# highway_mpg
# -0.22099999999999997
# city_mpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_221015/3027171293.py in <cell line: 5>()
#       7     print(i)
#       8     train_dict = df_train[lst].to_dict(orient='records')
# ----> 9     X_train = dv.fit_transform(train_dict)
#      10
#      11     val_dict = df_val[lst].to_dict(orient='records')
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# ~/.local/lib/python3.10/site-packages/sklearn/feature_extraction/_dict_vectorizer.py in fit_transform(self, X, y)
#     310         """
#     311         self._validate_params()
# --> 312         return self._transform(X, fitting=True)
#     313
#     314     def inverse_transform(self, X, dict_type=dict):
#
# ~/.local/lib/python3.10/site-packages/sklearn/feature_extraction/_dict_vectorizer.py in _transform(self, X, fitting)
#     257
#     258         if len(indptr) == 1:
# --> 259             raise ValueError("Sample sequence X is empty.")
#     260
#     261         indices = np.frombuffer(indices, dtype=np.intc)
#
# ValueError: Sample sequence X is empty.

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
for i in [0, 0.01, 0.1, 1, 10]:
    ridge_model = Ridge(solver='sag', random_state=42, alpha=i)
    ridge_model.fit(X_train, y_train)
    pred_y = ridge_model.predict(X_val)
    print(np.sqrt(mean_squared_error(y_val, pred_y)), i)
# Out:
# /home/beck/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 57378.32560238737 0
# /home/beck/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 57378.340570448214 0.01
# /home/beck/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 57378.47528124028 0.1
# /home/beck/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 57379.82192403147 1
# 57393.242390071224 10
# /home/beck/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
